# %% [markdown]
# # Basics

# %% [markdown]
# ## Mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Get and extract dataset

# %%
# !cp /content/drive/MyDrive/Ynov/deep_learning/data/stanford_dogo.rar /content/stanford_dogo.rar

# %%
# !unrar x /content/stanford_dogo.rar /content/
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/Saint_Bernard                      OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/Saluki                             OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/Samoyed                            OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/schipperke                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/Scotch_terrier                     OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/Scottish_deerhound                 OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/Sealyham_terrier                   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/Shetland_sheepdog                  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/Shih-Tzu                           OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/Siberian_husky                     OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/silky_terrier                      OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/soft-coated_wheaten_terrier        OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/Staffordshire_bullterrier          OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/standard_poodle                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/standard_schnauzer                 OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/Sussex_spaniel                     OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/Tibetan_mastiff                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/Tibetan_terrier                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/toy_poodle                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/toy_terrier                        OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/vizsla                             OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/Walker_hound                       OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/Weimaraner                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/Welsh_springer_spaniel             OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/West_Highland_white_terrier        OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/whippet                            OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/wire-haired_fox_terrier            OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/stanford_dogo/Yorkshire_terrier                  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
ls
# Out:
# augmented/  drive/  sample_data/  stanford_dogo/  stanford_dogo.rar

# %% [markdown]
# # Pre Treatment

# %% [markdown]
# ## Imports and test GPU

# %%
import numpy as np
import os
import cv2
import json
from google.colab.patches import cv2_imshow

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, BatchNormalization, Dropout, Activation, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy, Precision, Recall
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

from keras.applications.vgg16 import VGG16

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# ## Train test split

# %%
# !mkdir train
# !mkdir test

# %%
data_path = "/content/stanford_dogo/"
train_path = "/content/train/"
test_path = "/content/test/"
for folder_name in os.listdir(data_path):
    if not os.path.exists(os.path.join(train_path, folder_name)):
        os.mkdir(os.path.join(train_path, folder_name))
    if not os.path.exists(os.path.join(test_path, folder_name)):
        os.mkdir(os.path.join(test_path, folder_name))
    dogs = os.listdir(os.path.join(data_path, folder_name))
    for file_name in dogs[:int(0.8*len(dogs))]:
        os.rename(os.path.join(data_path, folder_name, file_name), os.path.join(train_path, folder_name, file_name))
    for file_name in dogs[int(0.8*len(dogs)):]:
        os.rename(os.path.join(data_path, folder_name, file_name), os.path.join(test_path, folder_name, file_name))

# %% [markdown]
# ## Datagen and data augmentation

# %%
datagen = ImageDataGenerator(
        rescale=1./255,
        zoom_range=0.2,
        rotation_range=30,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True,
        fill_mode='constant',
        cval=0,
        validation_split=0.2)

train_generator = datagen.flow_from_directory(
        train_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        subset='training')

val_generator = datagen.flow_from_directory(
        train_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        subset='validation')
# Out:
# Found 13172 images belonging to 120 classes.
# Found 3246 images belonging to 120 classes.

# %%
with open("class_indices.json", "w") as f:
    json.dump(train_generator.class_indices, f)

# %%
# !cp /content/class_indices.json /content/drive/MyDrive/Ynov/deep_learning/class_indices.json

# %% [markdown]
# ## Visualize augmented data

# %%
rm -r augmented

# %%
mkdir augmented

# %%
for file_name in val_generator.filenames:
    print(file_name)

# %%
i = 0
for batch in datagen.flow_from_directory(
        "/content/stanford_dogo/",
        target_size=(224, 224),
        batch_size=1,
        class_mode='categorical',
        subset='validation',
        save_to_dir='/content/augmented/'):

    i += 1
    if i > 20: # save 20 images
        break  # otherwise the generator would loop indefinitely
# Out:
# Found 4072 images belonging to 120 classes.

# %%
ls augmented/
# Out:
# _1037_8372329.png  _1806_4507403.png  _2676_5554397.png  _517_5553325.png
# _1038_9691534.png  _2019_8436319.png  _2872_1596770.png  _550_2410081.png
# _1046_27633.png    _2387_2237458.png  _3127_9797027.png  _699_4451598.png
# _1070_7550395.png  _2440_5234734.png  _3263_7161742.png
# _1197_6522583.png  _2507_6076217.png  _3697_1604763.png
# _1419_4968554.png  _2594_6474055.png  _3836_7872474.png

# %%
for filename in os.listdir("/content/augmented/"):
    print(filename)
    img = cv2.imread("/content/augmented/" + filename)
    cv2_imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Handcraft CNN

# %%
cnn = Sequential()

cnn.add(BatchNormalization(input_shape=(224, 224, 3)))
cnn.add(Conv2D(filters=16, kernel_size=3, kernel_initializer='he_normal', activation='relu'))
cnn.add(MaxPooling2D(pool_size=2))
cnn.add(BatchNormalization())

cnn.add(Conv2D(filters=32, kernel_size=3, kernel_initializer='he_normal', activation='relu'))
cnn.add(MaxPooling2D(pool_size=2))
cnn.add(BatchNormalization())

cnn.add(Conv2D(filters=64, kernel_size=3, kernel_initializer='he_normal', activation='relu'))
cnn.add(MaxPooling2D(pool_size=2))
cnn.add(BatchNormalization())

cnn.add(Conv2D(filters=128, kernel_size=3, kernel_initializer='he_normal', activation='relu'))
cnn.add(MaxPooling2D(pool_size=2))
cnn.add(BatchNormalization())

cnn.add(Conv2D(filters=256, kernel_size=3, kernel_initializer='he_normal', activation='relu'))
cnn.add(MaxPooling2D(pool_size=2))
cnn.add(BatchNormalization())

cnn.add(GlobalAveragePooling2D())

cnn.add(Dense(120, activation='softmax'))

cnn.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_6 (Batch (None, 224, 224, 3)       12
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 222, 222, 16)      448
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 111, 111, 16)      0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 111, 111, 16)      64
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 109, 109, 32)      4640
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 54, 54, 32)        0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 54, 54, 32)        128
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 52, 52, 64)        18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 26, 26, 64)        0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 26, 26, 64)        256
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 12, 12, 128)       512
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 10, 10, 256)       295168
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 5, 5, 256)         1024
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 120)               30840
# =================================================================
# Total params: 425,444
# Trainable params: 424,446
# Non-trainable params: 998
# _________________________________________________________________

# %%
cnn.compile(optimizer=Adam(),
              loss=CategoricalCrossentropy(),
              metrics=[CategoricalAccuracy(), Precision(), Recall()])

# %%
callbacks = [
    EarlyStopping(patience=5, verbose=1),
    #ReduceLROnPlateau(factor=0.2, patience=10, min_lr=0.00001, verbose=1),
    ModelCheckpoint('cnn_v5.h5', verbose=1, save_best_only=False, save_weights_only=False)
]

# %%
hist = cnn.fit(
        train_generator,
        epochs=100,
        validation_data=val_generator,
        callbacks=callbacks)
# Out:
# Epoch 1/100
# 412/412 [==============================] - 190s 460ms/step - loss: 4.7104 - categorical_accuracy: 0.0287 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 4.8358 - val_categorical_accuracy: 0.0351 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
#
# Epoch 00001: saving model to cnn_v5.h5
# Epoch 2/100
# 412/412 [==============================] - 189s 458ms/step - loss: 4.3151 - categorical_accuracy: 0.0559 - precision_3: 0.5780 - recall_3: 2.1683e-04 - val_loss: 4.2150 - val_categorical_accuracy: 0.0758 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
#
# Epoch 00002: saving model to cnn_v5.h5
# Epoch 3/100
# 412/412 [==============================] - 187s 454ms/step - loss: 4.0406 - categorical_accuracy: 0.0835 - precision_3: 0.3838 - recall_3: 2.7418e-04 - val_loss: 4.0634 - val_categorical_accuracy: 0.0964 - val_precision_3: 0.3182 - val_recall_3: 0.0022
#
# Epoch 00003: saving model to cnn_v5.h5
# Epoch 4/100
# 412/412 [==============================] - 186s 452ms/step - loss: 3.7684 - categorical_accuracy: 0.1292 - precision_3: 0.4357 - recall_3: 0.0025 - val_loss: 3.8561 - val_categorical_accuracy: 0.1282 - val_precision_3: 0.3382 - val_recall_3: 0.0142
#
# Epoch 00004: saving model to cnn_v5.h5
# Epoch 5/100
# 412/412 [==============================] - 187s 453ms/step - loss: 3.5711 - categorical_accuracy: 0.1611 - precision_3: 0.6142 - recall_3: 0.0080 - val_loss: 3.6303 - val_categorical_accuracy: 0.1503 - val_precision_3: 0.6410 - val_recall_3: 0.0077
#
# Epoch 00005: saving model to cnn_v5.h5
# Epoch 6/100
# 412/412 [==============================] - 186s 453ms/step - loss: 3.3621 - categorical_accuracy: 0.1970 - precision_3: 0.6603 - recall_3: 0.0150 - val_loss: 3.4952 - val_categorical_accuracy: 0.1741 - val_precision_3: 0.4791 - val_recall_3: 0.0317
#
# Epoch 00006: saving model to cnn_v5.h5
# Epoch 7/100
# 412/412 [==============================] - 186s 452ms/step - loss: 3.2103 - categorical_accuracy: 0.2239 - precision_3: 0.6875 - recall_3: 0.0277 - val_loss: 3.4280 - val_categorical_accuracy: 0.1892 - val_precision_3: 0.6700 - val_recall_3: 0.0206
#
# Epoch 00007: saving model to cnn_v5.h5
# Epoch 8/100
# 412/412 [==============================] - 190s 461ms/step - loss: 3.1027 - categorical_accuracy: 0.2489 - precision_3: 0.6884 - recall_3: 0.0361 - val_loss: 3.3589 - val_categorical_accuracy: 0.2024 - val_precision_3: 0.5636 - val_recall_3: 0.0478
#
# Epoch 00008: saving model to cnn_v5.h5
# Epoch 9/100
# 412/412 [==============================] - 189s 458ms/step - loss: 2.9445 - categorical_accuracy: 0.2720 - precision_3: 0.6902 - recall_3: 0.0504 - val_loss: 3.3580 - val_categorical_accuracy: 0.2157 - val_precision_3: 0.5012 - val_recall_3: 0.0638
#
# Epoch 00009: saving model to cnn_v5.h5
# Epoch 10/100
# 412/412 [==============================] - 190s 460ms/step - loss: 2.8128 - categorical_accuracy: 0.3056 - precision_3: 0.7216 - recall_3: 0.0700 - val_loss: 3.2410 - val_categorical_accuracy: 0.2218 - val_precision_3: 0.5067 - val_recall_3: 0.0582
#
# Epoch 00010: saving model to cnn_v5.h5
# Epoch 11/100
# 412/412 [==============================] - 189s 459ms/step - loss: 2.7138 - categorical_accuracy: 0.3296 - precision_3: 0.7240 - recall_3: 0.0869 - val_loss: 3.1206 - val_categorical_accuracy: 0.2588 - val_precision_3: 0.5950 - val_recall_3: 0.0887
#
# Epoch 00011: saving model to cnn_v5.h5
# Epoch 12/100
# 412/412 [==============================] - 188s 457ms/step - loss: 2.5881 - categorical_accuracy: 0.3550 - precision_3: 0.7328 - recall_3: 0.1027 - val_loss: 3.0687 - val_categorical_accuracy: 0.2563 - val_precision_3: 0.5935 - val_recall_3: 0.0841
#
# Epoch 00012: saving model to cnn_v5.h5
# Epoch 13/100
# 412/412 [==============================] - 187s 454ms/step - loss: 2.4995 - categorical_accuracy: 0.3602 - precision_3: 0.7510 - recall_3: 0.1176 - val_loss: 3.0333 - val_categorical_accuracy: 0.2794 - val_precision_3: 0.5897 - val_recall_3: 0.0921
#
# Epoch 00013: saving model to cnn_v5.h5
# Epoch 14/100
# 412/412 [==============================] - 187s 454ms/step - loss: 2.4328 - categorical_accuracy: 0.3716 - precision_3: 0.7518 - recall_3: 0.1375 - val_loss: 3.0421 - val_categorical_accuracy: 0.2606 - val_precision_3: 0.5245 - val_recall_3: 0.0958
#
# Epoch 00014: saving model to cnn_v5.h5
# Epoch 15/100
# 412/412 [==============================] - 188s 456ms/step - loss: 2.3446 - categorical_accuracy: 0.3872 - precision_3: 0.7408 - recall_3: 0.1567 - val_loss: 2.9742 - val_categorical_accuracy: 0.2751 - val_precision_3: 0.5668 - val_recall_3: 0.0980
#
# Epoch 00015: saving model to cnn_v5.h5
# Epoch 16/100
# 412/412 [==============================] - 187s 454ms/step - loss: 2.2903 - categorical_accuracy: 0.4032 - precision_3: 0.7473 - recall_3: 0.1687 - val_loss: 2.8728 - val_categorical_accuracy: 0.3056 - val_precision_3: 0.5685 - val_recall_3: 0.1445
#
# Epoch 00016: saving model to cnn_v5.h5
# Epoch 17/100
# 412/412 [==============================] - 189s 459ms/step - loss: 2.1804 - categorical_accuracy: 0.4347 - precision_3: 0.7616 - recall_3: 0.1973 - val_loss: 2.8368 - val_categorical_accuracy: 0.3078 - val_precision_3: 0.5764 - val_recall_3: 0.1371
#
# Epoch 00017: saving model to cnn_v5.h5
# Epoch 18/100
# 412/412 [==============================] - 190s 460ms/step - loss: 2.1321 - categorical_accuracy: 0.4460 - precision_3: 0.7783 - recall_3: 0.2100 - val_loss: 2.8534 - val_categorical_accuracy: 0.3068 - val_precision_3: 0.5760 - val_recall_3: 0.1436
#
# Epoch 00018: saving model to cnn_v5.h5
# Epoch 19/100
# 412/412 [==============================] - 189s 458ms/step - loss: 2.0693 - categorical_accuracy: 0.4544 - precision_3: 0.7694 - recall_3: 0.2225 - val_loss: 2.8693 - val_categorical_accuracy: 0.3025 - val_precision_3: 0.5504 - val_recall_3: 0.1531
#
# Epoch 00019: saving model to cnn_v5.h5
# Epoch 20/100
# 412/412 [==============================] - 188s 457ms/step - loss: 2.0203 - categorical_accuracy: 0.4679 - precision_3: 0.7855 - recall_3: 0.2426 - val_loss: 2.9834 - val_categorical_accuracy: 0.2902 - val_precision_3: 0.4990 - val_recall_3: 0.1577
#
# Epoch 00020: saving model to cnn_v5.h5
# Epoch 21/100
# 412/412 [==============================] - 189s 458ms/step - loss: 1.9667 - categorical_accuracy: 0.4770 - precision_3: 0.7772 - recall_3: 0.2493 - val_loss: 2.8517 - val_categorical_accuracy: 0.3253 - val_precision_3: 0.5357 - val_recall_3: 0.1731
#
# Epoch 00021: saving model to cnn_v5.h5
# Epoch 22/100
# 412/412 [==============================] - 189s 459ms/step - loss: 1.9391 - categorical_accuracy: 0.4807 - precision_3: 0.7744 - recall_3: 0.2650 - val_loss: 2.8382 - val_categorical_accuracy: 0.3222 - val_precision_3: 0.5562 - val_recall_3: 0.1845
#
# Epoch 00022: saving model to cnn_v5.h5
# Epoch 00022: early stopping

# %%
cp cnn_v5.h5 /content/drive/MyDrive/Ynov/deep_learning/cnn_v5.h5

# %% [markdown]
# ## Test Handcraft CNN

# %%
ls
# Out:
# augmented/          cnn_v5.h5     stanford_dogo/     train/
# class_indices.json  drive/        stanford_dogo.rar  vgg_v1.h5
# cnn_v4.h5           sample_data/  test/              vgg_v2.h5

# %%
indice_to_class = {}
for dog, indice in val_generator.class_indices.items():
    indice_to_class[indice] = dog

# %%
dogs = {}
for dog in val_generator.class_indices.keys():
    dogs[dog] = 0
for filename in os.listdir(os.path.join(test_path, "Afghan_hound/")):
    img = cv2.imread(os.path.join(test_path, "Afghan_hound/", filename))
    img = cv2.resize(img, (224, 224), interpolation = cv2.INTER_AREA)
    pred = cnn.predict(np.array([img]))
    #print(pred)
    dogs[indice_to_class[np.argmax(pred)]] += 1

# %%
dogs
# Out:
# {'Afghan_hound': 0,
#  'African_hunting_dog': 0,
#  'Airedale': 0,
#  'American_Staffordshire_terrier': 0,
#  'Appenzeller': 0,
#  'Australian_terrier': 0,
#  'Bedlington_terrier': 0,
#  'Bernese_mountain_dog': 0,
#  'Blenheim_spaniel': 0,
#  'Border_collie': 0,
#  'Border_terrier': 0,
#  'Boston_bull': 0,
#  'Bouvier_des_Flandres': 0,
#  'Brabancon_griffon': 0,
#  'Brittany_spaniel': 0,
#  'Cardigan': 0,
#  'Chesapeake_Bay_retriever': 0,
#  'Chihuahua': 0,
#  'Dandie_Dinmont': 0,
#  'Doberman': 0,
#  'English_foxhound': 0,
#  'English_setter': 0,
#  'English_springer': 0,
#  'EntleBucher': 0,
#  'Eskimo_dog': 0,
#  'French_bulldog': 0,
#  'German_shepherd': 0,
#  'German_short-haired_pointer': 0,
#  'Gordon_setter': 0,
#  'Great_Dane': 0,
#  'Great_Pyrenees': 0,
#  'Greater_Swiss_Mountain_dog': 0,
#  'Ibizan_hound': 0,
#  'Irish_setter': 0,
#  'Irish_terrier': 0,
#  'Irish_water_spaniel': 0,
#  'Irish_wolfhound': 0,
#  'Italian_greyhound': 0,
#  'Japanese_spaniel': 0,
#  'Kerry_blue_terrier': 0,
#  'Labrador_retriever': 0,
#  'Lakeland_terrier': 0,
#  'Leonberg': 0,
#  'Lhasa': 0,
#  'Maltese_dog': 0,
#  'Mexican_hairless': 0,
#  'Newfoundland': 0,
#  'Norfolk_terrier': 0,
#  'Norwegian_elkhound': 0,
#  'Norwich_terrier': 0,
#  'Old_English_sheepdog': 0,
#  'Pekinese': 0,
#  'Pembroke': 0,
#  'Pomeranian': 0,
#  'Rhodesian_ridgeback': 0,
#  'Rottweiler': 0,
#  'Saint_Bernard': 0,
#  'Saluki': 0,
#  'Samoyed': 0,
#  'Scotch_terrier': 0,
#  'Scottish_deerhound': 0,
#  'Sealyham_terrier': 0,
#  'Shetland_sheepdog': 0,
#  'Shih-Tzu': 0,
#  'Siberian_husky': 0,
#  'Staffordshire_bullterrier': 0,
#  'Sussex_spaniel': 9,
#  'Tibetan_mastiff': 31,
#  'Tibetan_terrier': 0,
#  'Walker_hound': 0,
#  'Weimaraner': 0,
#  'Welsh_springer_spaniel': 0,
#  'West_Highland_white_terrier': 0,
#  'Yorkshire_terrier': 0,
#  'affenpinscher': 0,
#  'basenji': 0,
#  'basset': 0,
#  'beagle': 0,
#  'black-and-tan_coonhound': 0,
#  'bloodhound': 0,
#  'bluetick': 0,
#  'borzoi': 0,
#  'boxer': 0,
#  'briard': 0,
#  'bull_mastiff': 0,
#  'cairn': 0,
#  'chow': 7,
#  'clumber': 0,
#  'cocker_spaniel': 0,
#  'collie': 0,
#  'curly-coated_retriever': 0,
#  'dhole': 0,
#  'dingo': 0,
#  'flat-coated_retriever': 0,
#  'giant_schnauzer': 0,
#  'golden_retriever': 0,
#  'groenendael': 0,
#  'keeshond': 0,
#  'kelpie': 0,
#  'komondor': 0,
#  'kuvasz': 0,
#  'malamute': 0,
#  'malinois': 0,
#  'miniature_pinscher': 0,
#  'miniature_poodle': 0,
#  'miniature_schnauzer': 0,
#  'otterhound': 1,
#  'papillon': 0,
#  'pug': 0,
#  'redbone': 0,
#  'schipperke': 0,
#  'silky_terrier': 0,
#  'soft-coated_wheaten_terrier': 0,
#  'standard_poodle': 0,
#  'standard_schnauzer': 0,
#  'toy_poodle': 0,
#  'toy_terrier': 0,
#  'vizsla': 0,
#  'whippet': 0,
#  'wire-haired_fox_terrier': 0}

# %%
dogs_accuracy = {}
count_total = 0
tp_total = 0
for folder_name in os.listdir(test_path):
    count = 0
    tp = 0
    for filename in os.listdir(os.path.join(test_path, folder_name)):
        try:
            img = cv2.imread(os.path.join(test_path, folder_name, filename))
            img = cv2.resize(img, (224, 224), interpolation = cv2.INTER_AREA)
            pred = cnn.predict(np.array([img]))
            count += 1
            count_total += 1
            if val_generator.class_indices[folder_name] == np.argmax(pred):
                tp += 1
                tp_total += 1
        except:
            print(f"error on {os.path.join(test_path, folder_name, filename)}")
    dogs_accuracy[folder_name] = tp / count
accuracy = tp_total / count_total

# %% [markdown]
# Accuracy sur le jeu de test :
#
#
# *   Sans data augmentation : 0.017
# *   Avec data augmentation : 0.004

# %%
accuracy
# Out:
# 0.004084574723690533

# %%
dogs_accuracy
# Out:
# {'Afghan_hound': 0.0,
#  'African_hunting_dog': 0.0,
#  'Airedale': 0.0,
#  'American_Staffordshire_terrier': 0.0,
#  'Appenzeller': 0.0,
#  'Australian_terrier': 0.0,
#  'Bedlington_terrier': 0.0,
#  'Bernese_mountain_dog': 0.0,
#  'Blenheim_spaniel': 0.0,
#  'Border_collie': 0.0,
#  'Border_terrier': 0.0,
#  'Boston_bull': 0.0,
#  'Bouvier_des_Flandres': 0.0,
#  'Brabancon_griffon': 0.0,
#  'Brittany_spaniel': 0.0,
#  'Cardigan': 0.0,
#  'Chesapeake_Bay_retriever': 0.0,
#  'Chihuahua': 0.0,
#  'Dandie_Dinmont': 0.0,
#  'Doberman': 0.0,
#  'English_foxhound': 0.0,
#  'English_setter': 0.0,
#  'English_springer': 0.0,
#  'EntleBucher': 0.0,
#  'Eskimo_dog': 0.0,
#  'French_bulldog': 0.0,
#  'German_shepherd': 0.0,
#  'German_short-haired_pointer': 0.0,
#  'Gordon_setter': 0.0,
#  'Great_Dane': 0.0,
#  'Great_Pyrenees': 0.0,
#  'Greater_Swiss_Mountain_dog': 0.0,
#  'Ibizan_hound': 0.0,
#  'Irish_setter': 0.0,
#  'Irish_terrier': 0.0,
#  'Irish_water_spaniel': 0.0,
#  'Irish_wolfhound': 0.0,
#  'Italian_greyhound': 0.0,
#  'Japanese_spaniel': 0.02702702702702703,
#  'Kerry_blue_terrier': 0.0,
#  'Labrador_retriever': 0.0,
#  'Lakeland_terrier': 0.0,
#  'Leonberg': 0.0,
#  'Lhasa': 0.0,
#  'Maltese_dog': 0.0,
#  'Mexican_hairless': 0.0,
#  'Newfoundland': 0.0,
#  'Norfolk_terrier': 0.0,
#  'Norwegian_elkhound': 0.0,
#  'Norwich_terrier': 0.0,
#  'Old_English_sheepdog': 0.0,
#  'Pekinese': 0.0,
#  'Pembroke': 0.0,
#  'Pomeranian': 0.0,
#  'Rhodesian_ridgeback': 0.0,
#  'Rottweiler': 0.0,
#  'Saint_Bernard': 0.0,
#  'Saluki': 0.0,
#  'Samoyed': 0.0,
#  'Scotch_terrier': 0.0,
#  'Scottish_deerhound': 0.0,
#  'Sealyham_terrier': 0.0,
#  'Shetland_sheepdog': 0.0,
#  'Shih-Tzu': 0.0,
#  'Siberian_husky': 0.0,
#  'Staffordshire_bullterrier': 0.0,
#  'Sussex_spaniel': 0.3225806451612903,
#  'Tibetan_mastiff': 0.16129032258064516,
#  'Tibetan_terrier': 0.0,
#  'Walker_hound': 0.0,
#  'Weimaraner': 0.0,
#  'Welsh_springer_spaniel': 0.0,
#  'West_Highland_white_terrier': 0.0,
#  'Yorkshire_terrier': 0.0,
#  'affenpinscher': 0.0,
#  'basenji': 0.0,
#  'basset': 0.0,
#  'beagle': 0.0,
#  'black-and-tan_coonhound': 0.0,
#  'bloodhound': 0.0,
#  'bluetick': 0.0,
#  'borzoi': 0.0,
#  'boxer': 0.0,
#  'briard': 0.0,
#  'bull_mastiff': 0.0,
#  'cairn': 0.0,
#  'chow': 0.025,
#  'clumber': 0.0,
#  'cocker_spaniel': 0.0,
#  'collie': 0.0,
#  'curly-coated_retriever': 0.0,
#  'dhole': 0.0,
#  'dingo': 0.0,
#  'flat-coated_retriever': 0.0,
#  'giant_schnauzer': 0.0,
#  'golden_retriever': 0.0,
#  'groenendael': 0.0,
#  'keeshond': 0.0,
#  'kelpie': 0.0,
#  'komondor': 0.0,
#  'kuvasz': 0.0,
#  'malamute': 0.0,
#  'malinois': 0.0,
#  'miniature_pinscher': 0.0,
#  'miniature_poodle': 0.0,
#  'miniature_schnauzer': 0.0,
#  'otterhound': 0.0,
#  'papillon': 0.0,
#  'pug': 0.0,
#  'redbone': 0.0,
#  'schipperke': 0.0,
#  'silky_terrier': 0.0,
#  'soft-coated_wheaten_terrier': 0.0,
#  'standard_poodle': 0.0,
#  'standard_schnauzer': 0.0,
#  'toy_poodle': 0.0,
#  'toy_terrier': 0.0,
#  'vizsla': 0.0,
#  'whippet': 0.0,
#  'wire-haired_fox_terrier': 0.0}

# %% [markdown]
# # Transfer Learning

# %%
vgg_org = VGG16()
vgg_org.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
vgg = Sequential()
for layer in vgg_org.layers[:-1]:
    layer.trainable = False
    vgg.add(layer)
vgg.add(Dense(120, activation='softmax'))

# %%
vgg.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense_5 (Dense)              (None, 120)               491640
# =================================================================
# Total params: 134,752,184
# Trainable params: 491,640
# Non-trainable params: 134,260,544
# _________________________________________________________________

# %%
vgg.compile(optimizer=Adam(),
              loss=CategoricalCrossentropy(),
              metrics=[CategoricalAccuracy(), Precision(), Recall()])

# %%
callbacks = [
    EarlyStopping(patience=5, verbose=1),
    #ReduceLROnPlateau(factor=0.2, patience=10, min_lr=0.00001, verbose=1),
    ModelCheckpoint('vgg_v3.h5', verbose=1, save_best_only=False, save_weights_only=False)
]

# %%
hist = vgg.fit(
        train_generator,
        epochs=100,
        validation_data=val_generator,
        callbacks=callbacks)
# Out:
# Epoch 1/100
# 412/412 [==============================] - 206s 498ms/step - loss: 5.6526 - categorical_accuracy: 0.0188 - precision_4: 0.1338 - recall_4: 6.0709e-05 - val_loss: 5.0229 - val_categorical_accuracy: 0.0447 - val_precision_4: 0.3333 - val_recall_4: 3.0807e-04
#
# Epoch 00001: saving model to vgg_v3.h5
# Epoch 2/100
# 412/412 [==============================] - 205s 498ms/step - loss: 4.8281 - categorical_accuracy: 0.0630 - precision_4: 0.3415 - recall_4: 0.0013 - val_loss: 4.6282 - val_categorical_accuracy: 0.0730 - val_precision_4: 0.4138 - val_recall_4: 0.0037
#
# Epoch 00002: saving model to vgg_v3.h5
# Epoch 3/100
# 412/412 [==============================] - 208s 505ms/step - loss: 4.5600 - categorical_accuracy: 0.0825 - precision_4: 0.3860 - recall_4: 0.0053 - val_loss: 4.5752 - val_categorical_accuracy: 0.0718 - val_precision_4: 0.4815 - val_recall_4: 0.0080
#
# Epoch 00003: saving model to vgg_v3.h5
# Epoch 4/100
# 412/412 [==============================] - 206s 501ms/step - loss: 4.3834 - categorical_accuracy: 0.1098 - precision_4: 0.4667 - recall_4: 0.0118 - val_loss: 4.5427 - val_categorical_accuracy: 0.1084 - val_precision_4: 0.4128 - val_recall_4: 0.0139
#
# Epoch 00004: saving model to vgg_v3.h5
# Epoch 5/100
# 412/412 [==============================] - 206s 499ms/step - loss: 4.3194 - categorical_accuracy: 0.1147 - precision_4: 0.4849 - recall_4: 0.0169 - val_loss: 4.4296 - val_categorical_accuracy: 0.0989 - val_precision_4: 0.3710 - val_recall_4: 0.0142
#
# Epoch 00005: saving model to vgg_v3.h5
# Epoch 6/100
# 412/412 [==============================] - 204s 496ms/step - loss: 4.2190 - categorical_accuracy: 0.1277 - precision_4: 0.4889 - recall_4: 0.0254 - val_loss: 4.3349 - val_categorical_accuracy: 0.1171 - val_precision_4: 0.4628 - val_recall_4: 0.0173
#
# Epoch 00006: saving model to vgg_v3.h5
# Epoch 7/100
# 412/412 [==============================] - 204s 496ms/step - loss: 4.0934 - categorical_accuracy: 0.1411 - precision_4: 0.4542 - recall_4: 0.0309 - val_loss: 4.2427 - val_categorical_accuracy: 0.1251 - val_precision_4: 0.4403 - val_recall_4: 0.0216
#
# Epoch 00007: saving model to vgg_v3.h5
# Epoch 8/100
# 412/412 [==============================] - 206s 500ms/step - loss: 4.0693 - categorical_accuracy: 0.1443 - precision_4: 0.5166 - recall_4: 0.0371 - val_loss: 4.3459 - val_categorical_accuracy: 0.1057 - val_precision_4: 0.3625 - val_recall_4: 0.0280
#
# Epoch 00008: saving model to vgg_v3.h5
# Epoch 9/100
# 412/412 [==============================] - 206s 499ms/step - loss: 4.0535 - categorical_accuracy: 0.1517 - precision_4: 0.5156 - recall_4: 0.0424 - val_loss: 4.2954 - val_categorical_accuracy: 0.1235 - val_precision_4: 0.4241 - val_recall_4: 0.0336
#
# Epoch 00009: saving model to vgg_v3.h5
# Epoch 10/100
# 412/412 [==============================] - 204s 496ms/step - loss: 3.9615 - categorical_accuracy: 0.1579 - precision_4: 0.5391 - recall_4: 0.0460 - val_loss: 4.4164 - val_categorical_accuracy: 0.1149 - val_precision_4: 0.2976 - val_recall_4: 0.0376
#
# Epoch 00010: saving model to vgg_v3.h5
# Epoch 11/100
# 412/412 [==============================] - 205s 498ms/step - loss: 3.8986 - categorical_accuracy: 0.1709 - precision_4: 0.5132 - recall_4: 0.0499 - val_loss: 4.3258 - val_categorical_accuracy: 0.1168 - val_precision_4: 0.4212 - val_recall_4: 0.0354
#
# Epoch 00011: saving model to vgg_v3.h5
# Epoch 12/100
# 412/412 [==============================] - 208s 505ms/step - loss: 3.8870 - categorical_accuracy: 0.1737 - precision_4: 0.5037 - recall_4: 0.0533 - val_loss: 4.1669 - val_categorical_accuracy: 0.1374 - val_precision_4: 0.4072 - val_recall_4: 0.0385
#
# Epoch 00012: saving model to vgg_v3.h5
# Epoch 13/100
# 412/412 [==============================] - 209s 507ms/step - loss: 3.8856 - categorical_accuracy: 0.1644 - precision_4: 0.4389 - recall_4: 0.0463 - val_loss: 4.4208 - val_categorical_accuracy: 0.1371 - val_precision_4: 0.3795 - val_recall_4: 0.0388
#
# Epoch 00013: saving model to vgg_v3.h5
# Epoch 14/100
# 412/412 [==============================] - 209s 508ms/step - loss: 3.8578 - categorical_accuracy: 0.1759 - precision_4: 0.5181 - recall_4: 0.0627 - val_loss: 4.1191 - val_categorical_accuracy: 0.1362 - val_precision_4: 0.3994 - val_recall_4: 0.0422
#
# Epoch 00014: saving model to vgg_v3.h5
# Epoch 15/100
# 412/412 [==============================] - 208s 504ms/step - loss: 3.7979 - categorical_accuracy: 0.1816 - precision_4: 0.4856 - recall_4: 0.0613 - val_loss: 4.0808 - val_categorical_accuracy: 0.1380 - val_precision_4: 0.4176 - val_recall_4: 0.0437
#
# Epoch 00015: saving model to vgg_v3.h5
# Epoch 16/100
# 412/412 [==============================] - 206s 500ms/step - loss: 3.8309 - categorical_accuracy: 0.1774 - precision_4: 0.4771 - recall_4: 0.0624 - val_loss: 4.2746 - val_categorical_accuracy: 0.1473 - val_precision_4: 0.4125 - val_recall_4: 0.0530
#
# Epoch 00016: saving model to vgg_v3.h5
# Epoch 17/100
# 412/412 [==============================] - 207s 502ms/step - loss: 3.7990 - categorical_accuracy: 0.1922 - precision_4: 0.5172 - recall_4: 0.0668 - val_loss: 4.2081 - val_categorical_accuracy: 0.1374 - val_precision_4: 0.3766 - val_recall_4: 0.0456
#
# Epoch 00017: saving model to vgg_v3.h5
# Epoch 18/100
# 412/412 [==============================] - 207s 502ms/step - loss: 3.7748 - categorical_accuracy: 0.1930 - precision_4: 0.4913 - recall_4: 0.0709 - val_loss: 4.0427 - val_categorical_accuracy: 0.1568 - val_precision_4: 0.4278 - val_recall_4: 0.0474
#
# Epoch 00018: saving model to vgg_v3.h5
# Epoch 19/100
# 412/412 [==============================] - 207s 503ms/step - loss: 3.6741 - categorical_accuracy: 0.2045 - precision_4: 0.5228 - recall_4: 0.0738 - val_loss: 4.2815 - val_categorical_accuracy: 0.1503 - val_precision_4: 0.4140 - val_recall_4: 0.0548
#
# Epoch 00019: saving model to vgg_v3.h5
# Epoch 20/100
# 412/412 [==============================] - 206s 500ms/step - loss: 3.6841 - categorical_accuracy: 0.2021 - precision_4: 0.5195 - recall_4: 0.0779 - val_loss: 4.1894 - val_categorical_accuracy: 0.1540 - val_precision_4: 0.3912 - val_recall_4: 0.0604
#
# Epoch 00020: saving model to vgg_v3.h5
# Epoch 21/100
# 412/412 [==============================] - 208s 505ms/step - loss: 3.6934 - categorical_accuracy: 0.2038 - precision_4: 0.5284 - recall_4: 0.0847 - val_loss: 4.1451 - val_categorical_accuracy: 0.1513 - val_precision_4: 0.4276 - val_recall_4: 0.0591
#
# Epoch 00021: saving model to vgg_v3.h5
# Epoch 22/100
# 412/412 [==============================] - 208s 504ms/step - loss: 3.6489 - categorical_accuracy: 0.2056 - precision_4: 0.5041 - recall_4: 0.0822 - val_loss: 4.0713 - val_categorical_accuracy: 0.1479 - val_precision_4: 0.3877 - val_recall_4: 0.0484
#
# Epoch 00022: saving model to vgg_v3.h5
# Epoch 23/100
# 412/412 [==============================] - 208s 505ms/step - loss: 3.7426 - categorical_accuracy: 0.2007 - precision_4: 0.5202 - recall_4: 0.0877 - val_loss: 4.2314 - val_categorical_accuracy: 0.1426 - val_precision_4: 0.3347 - val_recall_4: 0.0487
#
# Epoch 00023: saving model to vgg_v3.h5
# Epoch 00023: early stopping

# %%
cp vgg_v3.h5 /content/drive/MyDrive/Ynov/deep_learning/vgg_v3.h5

# %% [markdown]
# ## Test transfer learning

# %%
ls
# Out:
# augmented/          cnn_v5.h5     stanford_dogo/     train/     vgg_v3.h5
# class_indices.json  drive/        stanford_dogo.rar  vgg_v1.h5
# cnn_v4.h5           sample_data/  test/              vgg_v2.h5

# %%
indice_to_class = {}
for dog, indice in val_generator.class_indices.items():
    indice_to_class[indice] = dog

# %%
dogs = {}
for dog in val_generator.class_indices.keys():
    dogs[dog] = 0
for filename in os.listdir(os.path.join(test_path, "Afghan_hound/")):
    img = cv2.imread(os.path.join(test_path, "Afghan_hound/", filename))
    img = cv2.resize(img, (224, 224), interpolation = cv2.INTER_AREA)
    pred = vgg.predict(np.array([img]))
    dogs[indice_to_class[np.argmax(pred)]] += 1

# %%
dogs
# Out:
# {'Afghan_hound': 34,
#  'African_hunting_dog': 0,
#  'Airedale': 0,
#  'American_Staffordshire_terrier': 0,
#  'Appenzeller': 0,
#  'Australian_terrier': 0,
#  'Bedlington_terrier': 0,
#  'Bernese_mountain_dog': 0,
#  'Blenheim_spaniel': 0,
#  'Border_collie': 0,
#  'Border_terrier': 0,
#  'Boston_bull': 0,
#  'Bouvier_des_Flandres': 0,
#  'Brabancon_griffon': 0,
#  'Brittany_spaniel': 0,
#  'Cardigan': 0,
#  'Chesapeake_Bay_retriever': 0,
#  'Chihuahua': 0,
#  'Dandie_Dinmont': 0,
#  'Doberman': 0,
#  'English_foxhound': 0,
#  'English_setter': 1,
#  'English_springer': 0,
#  'EntleBucher': 0,
#  'Eskimo_dog': 0,
#  'French_bulldog': 0,
#  'German_shepherd': 0,
#  'German_short-haired_pointer': 0,
#  'Gordon_setter': 0,
#  'Great_Dane': 0,
#  'Great_Pyrenees': 0,
#  'Greater_Swiss_Mountain_dog': 0,
#  'Ibizan_hound': 0,
#  'Irish_setter': 0,
#  'Irish_terrier': 0,
#  'Irish_water_spaniel': 0,
#  'Irish_wolfhound': 0,
#  'Italian_greyhound': 0,
#  'Japanese_spaniel': 0,
#  'Kerry_blue_terrier': 0,
#  'Labrador_retriever': 0,
#  'Lakeland_terrier': 0,
#  'Leonberg': 0,
#  'Lhasa': 0,
#  'Maltese_dog': 0,
#  'Mexican_hairless': 0,
#  'Newfoundland': 1,
#  'Norfolk_terrier': 0,
#  'Norwegian_elkhound': 0,
#  'Norwich_terrier': 0,
#  'Old_English_sheepdog': 0,
#  'Pekinese': 0,
#  'Pembroke': 0,
#  'Pomeranian': 0,
#  'Rhodesian_ridgeback': 0,
#  'Rottweiler': 0,
#  'Saint_Bernard': 0,
#  'Saluki': 6,
#  'Samoyed': 0,
#  'Scotch_terrier': 2,
#  'Scottish_deerhound': 0,
#  'Sealyham_terrier': 0,
#  'Shetland_sheepdog': 0,
#  'Shih-Tzu': 0,
#  'Siberian_husky': 0,
#  'Staffordshire_bullterrier': 0,
#  'Sussex_spaniel': 3,
#  'Tibetan_mastiff': 0,
#  'Tibetan_terrier': 0,
#  'Walker_hound': 0,
#  'Weimaraner': 0,
#  'Welsh_springer_spaniel': 0,
#  'West_Highland_white_terrier': 0,
#  'Yorkshire_terrier': 0,
#  'affenpinscher': 1,
#  'basenji': 0,
#  'basset': 0,
#  'beagle': 0,
#  'black-and-tan_coonhound': 0,
#  'bloodhound': 0,
#  'bluetick': 0,
#  'borzoi': 0,
#  'boxer': 0,
#  'briard': 0,
#  'bull_mastiff': 0,
#  'cairn': 0,
#  'chow': 0,
#  'clumber': 0,
#  'cocker_spaniel': 0,
#  'collie': 0,
#  'curly-coated_retriever': 0,
#  'dhole': 0,
#  'dingo': 0,
#  'flat-coated_retriever': 0,
#  'giant_schnauzer': 0,
#  'golden_retriever': 0,
#  'groenendael': 0,
#  'keeshond': 0,
#  'kelpie': 0,
#  'komondor': 0,
#  'kuvasz': 0,
#  'malamute': 0,
#  'malinois': 0,
#  'miniature_pinscher': 0,
#  'miniature_poodle': 0,
#  'miniature_schnauzer': 0,
#  'otterhound': 0,
#  'papillon': 0,
#  'pug': 0,
#  'redbone': 0,
#  'schipperke': 0,
#  'silky_terrier': 0,
#  'soft-coated_wheaten_terrier': 0,
#  'standard_poodle': 0,
#  'standard_schnauzer': 0,
#  'toy_poodle': 0,
#  'toy_terrier': 0,
#  'vizsla': 0,
#  'whippet': 0,
#  'wire-haired_fox_terrier': 0}

# %%
dogs_accuracy = {}
count_total = 0
tp_total = 0
for folder_name in os.listdir(test_path):
    count = 0
    tp = 0
    for filename in os.listdir(os.path.join(test_path, folder_name)):
        try:
            img = cv2.imread(os.path.join(test_path, folder_name, filename))
            img = cv2.resize(img, (224, 224), interpolation = cv2.INTER_AREA)
            pred = vgg.predict(np.array([img]))
            count += 1
            count_total += 1
            if val_generator.class_indices[folder_name] == np.argmax(pred):
                tp += 1
                tp_total += 1
        except:
            print(f"error on {os.path.join(test_path, folder_name, filename)}")
    dogs_accuracy[folder_name] = tp / count
accuracy = tp_total / count_total

# %% [markdown]
# Accuracy sur le jeu de test :
#
#
# *   Sans data augmentation : 0.21
# *   Avec data augmentation : 0.23

# %%
accuracy
# Out:
# 0.22921672272945698

# %%
dogs_accuracy
# Out:
# {'Afghan_hound': 0.7083333333333334,
#  'African_hunting_dog': 0.6470588235294118,
#  'Airedale': 0.0,
#  'American_Staffordshire_terrier': 0.12121212121212122,
#  'Appenzeller': 0.0,
#  'Australian_terrier': 0.175,
#  'Bedlington_terrier': 0.32432432432432434,
#  'Bernese_mountain_dog': 0.0,
#  'Blenheim_spaniel': 0.2631578947368421,
#  'Border_collie': 0.3,
#  'Border_terrier': 0.0,
#  'Boston_bull': 0.7297297297297297,
#  'Bouvier_des_Flandres': 0.26666666666666666,
#  'Brabancon_griffon': 0.03225806451612903,
#  'Brittany_spaniel': 0.0,
#  'Cardigan': 0.5806451612903226,
#  'Chesapeake_Bay_retriever': 0.0,
#  'Chihuahua': 0.12903225806451613,
#  'Dandie_Dinmont': 0.3055555555555556,
#  'Doberman': 0.0,
#  'English_foxhound': 0.875,
#  'English_setter': 0.42424242424242425,
#  'English_springer': 0.03125,
#  'EntleBucher': 0.024390243902439025,
#  'Eskimo_dog': 0.03333333333333333,
#  'French_bulldog': 0.3125,
#  'German_shepherd': 0.0,
#  'German_short-haired_pointer': 0.06451612903225806,
#  'Gordon_setter': 0.03225806451612903,
#  'Great_Dane': 0.6875,
#  'Great_Pyrenees': 0.0,
#  'Greater_Swiss_Mountain_dog': 0.47058823529411764,
#  'Ibizan_hound': 0.18421052631578946,
#  'Irish_setter': 0.0,
#  'Irish_terrier': 0.0,
#  'Irish_water_spaniel': 0.1,
#  'Irish_wolfhound': 0.022727272727272728,
#  'Italian_greyhound': 0.24324324324324326,
#  'Japanese_spaniel': 0.918918918918919,
#  'Kerry_blue_terrier': 0.3333333333333333,
#  'Labrador_retriever': 0.02857142857142857,
#  'Lakeland_terrier': 0.025,
#  'Leonberg': 0.0,
#  'Lhasa': 0.02631578947368421,
#  'Maltese_dog': 0.6078431372549019,
#  'Mexican_hairless': 0.5161290322580645,
#  'Newfoundland': 0.41025641025641024,
#  'Norfolk_terrier': 0.0,
#  'Norwegian_elkhound': 0.35,
#  'Norwich_terrier': 0.08108108108108109,
#  'Old_English_sheepdog': 0.0,
#  'Pekinese': 0.0,
#  'Pembroke': 0.0,
#  'Pomeranian': 0.045454545454545456,
#  'Rhodesian_ridgeback': 0.0,
#  'Rottweiler': 0.16129032258064516,
#  'Saint_Bernard': 0.6176470588235294,
#  'Saluki': 0.475,
#  'Samoyed': 0.7954545454545454,
#  'Scotch_terrier': 0.96875,
#  'Scottish_deerhound': 0.0,
#  'Sealyham_terrier': 0.2682926829268293,
#  'Shetland_sheepdog': 0.0625,
#  'Shih-Tzu': 0.06976744186046512,
#  'Siberian_husky': 0.5897435897435898,
#  'Staffordshire_bullterrier': 0.0,
#  'Sussex_spaniel': 0.6129032258064516,
#  'Tibetan_mastiff': 0.06451612903225806,
#  'Tibetan_terrier': 0.16666666666666666,
#  'Walker_hound': 0.0,
#  'Weimaraner': 0.0,
#  'Welsh_springer_spaniel': 0.0,
#  'West_Highland_white_terrier': 0.23529411764705882,
#  'Yorkshire_terrier': 0.45454545454545453,
#  'affenpinscher': 0.5,
#  'basenji': 0.7857142857142857,
#  'basset': 0.11428571428571428,
#  'beagle': 0.5641025641025641,
#  'black-and-tan_coonhound': 0.03125,
#  'bloodhound': 0.05263157894736842,
#  'bluetick': 0.0,
#  'borzoi': 0.5161290322580645,
#  'boxer': 0.03225806451612903,
#  'briard': 0.0,
#  'bull_mastiff': 0.03125,
#  'cairn': 0.0,
#  'chow': 0.575,
#  'clumber': 0.0,
#  'cocker_spaniel': 0.0,
#  'collie': 0.0,
#  'curly-coated_retriever': 0.5483870967741935,
#  'dhole': 0.0,
#  'dingo': 0.25,
#  'flat-coated_retriever': 0.0,
#  'giant_schnauzer': 0.0,
#  'golden_retriever': 0.0,
#  'groenendael': 0.43333333333333335,
#  'keeshond': 0.34375,
#  'kelpie': 0.12903225806451613,
#  'komondor': 0.4838709677419355,
#  'kuvasz': 0.6333333333333333,
#  'malamute': 0.1111111111111111,
#  'malinois': 0.03333333333333333,
#  'miniature_pinscher': 0.05405405405405406,
#  'miniature_poodle': 0.0967741935483871,
#  'miniature_schnauzer': 0.3225806451612903,
#  'otterhound': 0.7096774193548387,
#  'papillon': 0.7,
#  'pug': 0.0,
#  'redbone': 0.0,
#  'schipperke': 0.6451612903225806,
#  'silky_terrier': 0.24324324324324326,
#  'soft-coated_wheaten_terrier': 0.0,
#  'standard_poodle': 0.15625,
#  'standard_schnauzer': 0.3225806451612903,
#  'toy_poodle': 0.06451612903225806,
#  'toy_terrier': 0.05714285714285714,
#  'vizsla': 0.0,
#  'whippet': 0.02631578947368421,
#  'wire-haired_fox_terrier': 0.46875}
